# %%
import networkx as nx
from pathlib import Path

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from flinspect.parse_tree import ParseTree
from flinspect.parse_forest import ParseForest

# %%
build_dirs = [
    "/glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS2/",
    "/glade/work/altuntas/turbo-stack/bin/flang_ptree/MOM6-infra",
    "/glade/work/altuntas/turbo-stack/bin/flang_ptree/MOM6"
]

parse_tree_paths = [f for dir in build_dirs for f in Path(dir).glob("*_ptree")]

# %%
pf = ParseForest(parse_tree_paths)
# Out:
# Warning: Skipping CMakeCCompilerId.o_ptree as it does not start with proper header.
# Warning: Skipping mpp_memuse.o_ptree as it does not start with proper header.
# Warning: Skipping fms_string_utils_binding.o_ptree as it does not start with proper header.
# Warning: Skipping mppnccombine.o_ptree as it does not start with proper header.
# Warning: Skipping mosaic_util.o_ptree as it does not start with proper header.
# Warning: Skipping gradient_c2l.o_ptree as it does not start with proper header.
# Warning: Skipping affinity.o_ptree as it does not start with proper header.
# Warning: Skipping interp.o_ptree as it does not start with proper header.
# Warning: Skipping read_mosaic.o_ptree as it does not start with proper header.
# Warning: Skipping create_xgrid.o_ptree as it does not start with proper header.
# Warning: Skipping yaml_parser_binding.o_ptree as it does not start with proper header.
# Warning: Skipping yaml_output_functions.o_ptree as it does not start with proper header.

# %%
nr = pf.registry

# %% [markdown]
# # Module Dependency Analysis

# %%
G = pf.get_module_dependency_graph()
# Out:
# Skipped 8 modules with unknown parse tree paths: ['netcdf', 'iso_c_binding', 'mpi', 'iso_fortran_env', 'netcdf_nf_data', 'netcdf_nf_interfaces', 'netcdf4_nf_interfaces', 'omp_lib']

# %%
# Determine source paths via the path_names files in build dirs
# This will be used to color nodes and edges based on where modules are located
path_names = {}
for build_dir in build_dirs:
    path_names_file = Path(build_dir)/"path_names"
    with open(path_names_file) as f:
        for line in f:
            src_file_path = Path(line.strip())
            path_names[src_file_path.stem.lower()] = src_file_path.as_posix()

# %%
# Find all nodes where /FMS/ is in the source path
fms_nodes = [node for node in G.nodes() if "/FMS/" in path_names.get(G.nodes[node].get('source_name','').lower(),'')]

# %%
# Find all fms_nodes that have no incoming edges (i.e., no dependencies)
fms_root_nodes = [node for node in fms_nodes if G.in_degree(node) == 0]

for fms_root_node in fms_root_nodes:
    print(fms_root_node, path_names.get(G.nodes[fms_root_node].get('source_name','').lower(),''))
# Out:
# mpp_pset_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_pset.F90
# drifters_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters.F90
# grid_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mosaic/grid.F90
# fms_yaml_output_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/parser/fms_yaml_output.F90
# fm_yaml_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/field_manager/fm_yaml.F90
# fms /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/libFMS.F90
# time_interp_external_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/time_interp/time_interp_external.F90
# constantsr4_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/constants4/constantsr4.F90

# %%
# Find all FMS nodes that is not needed by any other FMS nodes
fms_leaf_nodes = [node for node in fms_nodes if G.out_degree(node) == 0]

for fms_leaf_node in fms_leaf_nodes:
    print(fms_leaf_node, path_names.get(G.nodes[fms_leaf_node].get('source_name','').lower(),''))
# Out:
# platform_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/platform/platform.F90
# cloud_interpolator_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/cloud_interpolator.F90
# monin_obukhov_inter /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/monin_obukhov/monin_obukhov_inter.F90
# mersennetwister_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/random_numbers/mersennetwister.F90
# fms_yaml_output_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/parser/fms_yaml_output.F90
# fm_yaml_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/field_manager/fm_yaml.F90
# yaml_parser_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/parser/yaml_parser.F90
# tridiagonal_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/tridiagonal/tridiagonal.F90

# %%
# Find all MOM6 nodes:
mom6_nodes = [node for node in G.nodes() if "/MOM6/" in path_names.get(G.nodes[node].get('source_name','').lower(),'')]

# Find all FMS nodes that is not needed by any other MOM6 nodes recursively (i.e. transitive closure)
mom6_deps = set()
for mom6_node in mom6_nodes:
    mom6_deps.update(nx.descendants(G, mom6_node))

# Find all FMS nodes that are not needed by any other MOM6 nodes
fms_leaf_nodes = [node for node in fms_nodes if all(pred not in mom6_deps for pred in G.predecessors(node))]

for fms_leaf_node in fms_leaf_nodes:
    print(fms_leaf_node, path_names.get(G.nodes[fms_leaf_node].get('source_name','').lower(),''))
# Out:
# mpp_pset_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_pset.F90
# drifters_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters.F90
# drifters_core_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters_core.F90
# cloud_interpolator_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/cloud_interpolator.F90
# drifters_input_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters_input.F90
# drifters_comm_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters_comm.F90
# drifters_io_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters_io.F90
# monin_obukhov_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/monin_obukhov/monin_obukhov.F90
# monin_obukhov_inter /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/monin_obukhov/monin_obukhov_inter.F90
# grid_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mosaic/grid.F90
# mosaic_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mosaic/mosaic.F90
# fms_yaml_output_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/parser/fms_yaml_output.F90
# diag_integral_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/diag_integral/diag_integral.F90
# fmsconstantsr4 /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/constants4/fmsconstantsr4.F90
# column_diagnostics_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/column_diagnostics/column_diagnostics.F90
# fm_yaml_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/field_manager/fm_yaml.F90
# amip_interp_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/amip_interp/amip_interp.F90
# xgrid_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/exchange/xgrid.F90
# gradient_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mosaic/gradient.F90
# stock_constants_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/exchange/stock_constants.F90
# tracer_manager_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/tracer_manager/tracer_manager.F90
# mpp_utilities_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_utilities.F90
# gaussian_topog_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/topography/gaussian_topog.F90
# fms /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/libFMS.F90
# block_control_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/block_control/block_control.F90
# interpolator_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/interpolator/interpolator.F90
# sat_vapor_pres_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/sat_vapor_pres/sat_vapor_pres.F90
# topography_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/topography/topography.F90
# tridiagonal_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/tridiagonal/tridiagonal.F90
# sat_vapor_pres_k_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/sat_vapor_pres/sat_vapor_pres_k.F90
# time_interp_external_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/time_interp/time_interp_external.F90
# axis_utils_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/axis_utils/axis_utils.F90
# constantsr4_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/constants4/constantsr4.F90

# %% [markdown]
# # Call Graph Analysis

# %%
path_names = {}
for build_dir in build_dirs:
    path_names_file = Path(build_dir)/"path_names"
    with open(path_names_file) as f:
        for line in f:
            src_file_path = Path(line.strip())
            path_names[src_file_path.stem.lower()] = src_file_path.as_posix()

# %%
gsc = pf.get_call_graph()
# Out:
# Warning: Skipping CMakeCCompilerId.o_ptree as it does not start with proper header.
# Warning: Skipping mpp_memuse.o_ptree as it does not start with proper header.
# Warning: Skipping fms_string_utils_binding.o_ptree as it does not start with proper header.
# Warning: Skipping mppnccombine.o_ptree as it does not start with proper header.
# Warning: Skipping mosaic_util.o_ptree as it does not start with proper header.
# Warning: Skipping gradient_c2l.o_ptree as it does not start with proper header.
# Warning: Skipping affinity.o_ptree as it does not start with proper header.
# Warning: Skipping interp.o_ptree as it does not start with proper header.
# Warning: Skipping read_mosaic.o_ptree as it does not start with proper header.
# Warning: Skipping create_xgrid.o_ptree as it does not start with proper header.
# Warning: Skipping yaml_parser_binding.o_ptree as it does not start with proper header.
# Warning: Skipping yaml_output_functions.o_ptree as it does not start with proper header.
# Warning: Skipping CMakeCCompilerId.o_ptree as it does not start with proper header.
# Warning: Skipping mpp_memuse.o_ptree as it does not start with proper header.
# Warning: Skipping fms_string_utils_binding.o_ptree as it does not start with proper header.
# Warning: Skipping mppnccombine.o_ptree as it does not start with proper header.
# Warning: Skipping mosaic_util.o_ptree as it does not start with proper header.
# Warning: Skipping gradient_c2l.o_ptree as it does not start with proper header.
# Warning: Skipping affinity.o_ptree as it does not start with proper header.
# Warning: Skipping interp.o_ptree as it does not start with proper header.
# Warning: Skipping read_mosaic.o_ptree as it does not start with proper header.
# Warning: Skipping create_xgrid.o_ptree as it does not start with proper header.
# Warning: Skipping yaml_parser_binding.o_ptree as it does not start with proper header.
# Warning: Skipping yaml_output_functions.o_ptree as it does not start with proper header.
# Total unfound calls across all parse trees: 195
# Total unfound function calls across all parse trees: 78829

# %%
# Find all FMS subroutines and MOM6 subroutines
all_fms_routines = []
all_mom6_routines = []
for node in gsc.nodes():
    try:
        module_path = node.program_unit.parse_tree_path
        source_path = path_names.get(module_path.stem.lower(),'')
    except AttributeError:
        continue
    if "/MOM6/" in source_path:
        all_mom6_routines.append(node)
    elif "/FMS/" in source_path:
        all_fms_routines.append(node)

# %%
len(all_mom6_routines), len(all_fms_routines)
# Out:
# (3525, 2956)

# %%
def get_fms_subroutines_needed_by_mom6(gsc, all_mom6_routines):
    fms_subroutines_needed_by_mom6 = set()
    for mom6_routine in all_mom6_routines:
        descendants = nx.descendants(gsc, mom6_routine)
        for desc in descendants:
            try:
                module_path = desc.program_unit.parse_tree_path
                source_path = path_names.get(module_path.stem.lower(),'')
            except AttributeError:
                continue
            if "/FMS/" in source_path:
                fms_subroutines_needed_by_mom6.add(desc)
    return fms_subroutines_needed_by_mom6

# %%
fms_subroutines_needed_by_mom6 = get_fms_subroutines_needed_by_mom6(gsc, all_mom6_routines)

# %%
len(fms_subroutines_needed_by_mom6)
# Out:
# 1485

# %%
fms_subroutines_NOT_needed_by_mom6 = [r for r in all_fms_routines if r not in fms_subroutines_needed_by_mom6]
len(fms_subroutines_NOT_needed_by_mom6)
# Out:
# 1471

# %%
# find all FMS subroutines that are not needed by MOM6 and are not called by any other FMS subroutines
fms_subroutines_NOT_needed_by_mom6_and_not_called_by_fms = []
for routine in fms_subroutines_NOT_needed_by_mom6:
    callers = list(gsc.predecessors(routine))
    called_by_fms = False
    for caller in callers:
        try:
            module_path = caller.program_unit.parse_tree_path
            source_path = path_names.get(module_path.stem.lower(),'')
        except AttributeError:
            continue
        if "/FMS/" in source_path:
            called_by_fms = True
            break
    if not called_by_fms:
        fms_subroutines_NOT_needed_by_mom6_and_not_called_by_fms.append(routine)

# %%
len(fms_subroutines_NOT_needed_by_mom6_and_not_called_by_fms)
# Out:
# 608

# %%
for routine in fms_subroutines_NOT_needed_by_mom6_and_not_called_by_fms:
    if 'mpp_io' in routine.program_unit.name:
        print(routine.name)
# Out:
# mpp_get_time_axis
# mpp_flush
# mpp_write_axis_data
# mpp_copy_meta_global
# mpp_copy_meta_axis
# mpp_copy_meta_field
# fillin_fieldtype
# mpp_get_default_calendar
# mpp_get_field_index
# mpp_get_axis_index
# mpp_get_axis_by_name
# mpp_get_axis_length
# mpp_get_recdimid
# mpp_get_ncid
# mpp_get_axis_id
# mpp_get_field_id
# mpp_get_att_type
# mpp_get_att_real
# mpp_get_field_name
# mpp_io_clock_on
# mpp_get_maxunits
# do_cf_compliance

# %%
fms_subroutines_NOT_needed_by_mom6_and_not_called_by_fms[10:]
# Out:
# [Subroutine('mpp_pset_stack_reset'),
#  Subroutine('mpp_pset_print_stack_chksum'),
#  Subroutine('mpp_pset_get_root_pelist'),
#  Subroutine('diag_axis_add_attribute_scalar_r'),
#  Subroutine('diag_axis_add_attribute_scalar_i'),
#  Subroutine('diag_axis_add_attribute_scalar_c'),
#  Subroutine('fms_sort_this'),
#  Subroutine('c_free'),
#  Subroutine('fms_f2c_string'),
#  Subroutine('drifters_new'),
#  Subroutine('drifters_copy_new'),
#  Subroutine('drifters_set_domain'),
#  Subroutine('drifters_set_pe_neighbors'),
#  Subroutine('drifters_push_2'),
#  Subroutine('drifters_push_3'),
#  Subroutine('drifters_set_field_2d'),
#  Subroutine('drifters_set_field_3d'),
#  Subroutine('drifters_save'),
#  Subroutine('drifters_distribute'),
#  Subroutine('drifters_write_restart'),
#  Subroutine('drifters_set_v_axes'),
#  Subroutine('drifters_set_domain_bounds'),
#  Subroutine('drifters_print_checksums'),
#  Subroutine('drifters_comm_set_data_bounds'),
#  Subroutine('drifters_comm_set_comp_bounds'),
#  Subroutine('tranlon'),
#  Subroutine('interp_1d_1d'),
#  Subroutine('interp_1d_2d'),
#  Subroutine('interp_1d_3d'),
#  Subroutine('monin_obukhov_init'),
#  Subroutine('monin_obukhov_end'),
#  Subroutine('solve_zeta'),
#  Subroutine('mo_drag_2d'),
#  Subroutine('mo_drag_0d'),
#  Subroutine('mo_profile_1d_n'),
#  Subroutine('mo_profile_0d_n'),
#  Subroutine('mo_profile_2d_n'),
#  Subroutine('mo_diff_2d_1'),
#  Subroutine('mo_diff_1d_1'),
#  Subroutine('mo_diff_1d_n'),
#  Subroutine('mo_diff_0d_1'),
#  Subroutine('mo_diff_0d_n'),
#  Subroutine('stable_mix_2d'),
#  Subroutine('stable_mix_1d'),
#  Subroutine('stable_mix_0d'),
#  Subroutine('astronomy_init'),
#  Subroutine('get_period_integer'),
#  Subroutine('get_period_time_type'),
#  Subroutine('set_period_integer'),
#  Subroutine('set_period_time_type'),
#  Subroutine('set_orbital_parameters'),
#  Subroutine('get_orbital_parameters'),
#  Subroutine('set_ref_date_of_ae'),
#  Subroutine('get_ref_date_of_ae'),
#  Subroutine('annual_mean_solar_1d'),
#  Subroutine('annual_mean_solar_2level'),
#  Subroutine('astronomy_end'),
#  Subroutine('get_grid_comp_area_ug'),
#  Subroutine('get_grid_cell_centers_1d'),
#  Subroutine('get_grid_cell_centers_ug'),
#  Subroutine('define_cube_mosaic'),
#  Subroutine('finalize_randomnumbersequence'),
#  Subroutine('diag_grid_init'),
#  Subroutine('diag_grid_end'),
#  Subroutine('get_local_indexes2'),
#  Subroutine('reset_bounds'),
#  Subroutine('update_bounds'),
#  Subroutine('reset_bounds_from_array_4d'),
#  Subroutine('reset_bounds_from_array_5d'),
#  Subroutine('diag_integral_init'),
#  Subroutine('diag_integral_field_init'),
#  Subroutine('sum_field_2d'),
#  Subroutine('sum_field_3d'),
#  Subroutine('sum_field_wght_3d'),
#  Subroutine('sum_field_2d_hemi'),
#  Subroutine('diag_integral_output'),
#  Subroutine('diag_integral_end'),
#  Subroutine('fieldbuff_copy_missvals_3d_r4'),
#  Subroutine('fieldbuff_copy_missvals_3d_r8'),
#  Subroutine('fmsconstantsr4_init'),
#  Subroutine('diag_send_complete_instant'),
#  Subroutine('diag_field_add_cell_measures'),
#  Subroutine('openmp_thread_trap'),
#  Subroutine('append_to_list'),
#  Subroutine('destroy_list'),
#  Subroutine('nullify_filename_appendix'),
#  Subroutine('mpp_define_nest_domains'),
#  Subroutine('mpp_shift_nest_domains'),
#  Subroutine('print_nest_overlap'),
#  Subroutine('mpp_get_c2f_index'),
#  Subroutine('mpp_get_f2c_index_fine'),
#  Subroutine('mpp_get_f2c_index_coarse'),
#  Subroutine('get_nnest'),
#  Subroutine('convert_index_back'),
#  Subroutine('mpp_get_nest_pelist'),
#  Subroutine('mpp_get_nest_fine_pelist'),
#  Subroutine('mpp_create_super_grid_domain'),
#  Subroutine('nullify_domain2d_list'),
#  Subroutine('mpp_get_tile_pelist'),
#  Subroutine('mpp_get_tile_compute_domains'),
#  Subroutine('mpp_get_update_size'),
#  Subroutine('mpp_get_update_pelist'),
#  Subroutine('mpp_get_overlap'),
#  Subroutine('mpp_set_domain_symmetry'),
#  Subroutine('mpp_copy_domain2d'),
#  Subroutine('mpp_clear_group_update'),
#  Subroutine('mpp_global_field_free_comm'),
#  Subroutine('mpp_define_mosaic_pelist'),
#  Subroutine('mpp_check_field_3d'),
#  Subroutine('mpp_do_update_ad_i8_3d'),
#  Subroutine('mpp_do_update_ad_i4_3d'),
#  Subroutine('mpp_get_boundary_ad_r8_2d'),
#  Subroutine('mpp_get_boundary_ad_r8_3d'),
#  Subroutine('mpp_get_boundary_ad_r8_2dv'),
#  Subroutine('mpp_get_boundary_ad_r8_3dv'),
#  Subroutine('mpp_get_boundary_ad_r4_2d'),
#  Subroutine('mpp_get_boundary_ad_r4_3d'),
#  Subroutine('mpp_get_boundary_ad_r4_2dv'),
#  Subroutine('mpp_get_boundary_ad_r4_3dv'),
#  Subroutine('mpp_global_sum_tl_r8_2d'),
#  Subroutine('mpp_global_sum_tl_r8_3d'),
#  Subroutine('mpp_global_sum_tl_r8_4d'),
#  Subroutine('mpp_global_sum_tl_r8_5d'),
#  Subroutine('mpp_global_sum_tl_r4_2d'),
#  Subroutine('mpp_global_sum_tl_r4_3d'),
#  Subroutine('mpp_global_sum_tl_r4_4d'),
#  Subroutine('mpp_global_sum_tl_r4_5d'),
#  Subroutine('mpp_global_sum_tl_i8_2d'),
#  Subroutine('mpp_global_sum_tl_i8_3d'),
#  Subroutine('mpp_global_sum_tl_i8_4d'),
#  Subroutine('mpp_global_sum_tl_i8_5d'),
#  Subroutine('mpp_global_sum_tl_i4_2d'),
#  Subroutine('mpp_global_sum_tl_i4_3d'),
#  Subroutine('mpp_global_sum_tl_i4_4d'),
#  Subroutine('mpp_global_sum_tl_i4_5d'),
#  Subroutine('mpp_global_sum_ad_r8_2d'),
#  Subroutine('mpp_global_sum_ad_r8_3d'),
#  Subroutine('mpp_global_sum_ad_r8_4d'),
#  Subroutine('mpp_global_sum_ad_r8_5d'),
#  Subroutine('mpp_global_sum_ad_r4_2d'),
#  Subroutine('mpp_global_sum_ad_r4_3d'),
#  Subroutine('mpp_global_sum_ad_r4_4d'),
#  Subroutine('mpp_global_sum_ad_r4_5d'),
#  Subroutine('mpp_global_sum_ad_i8_2d'),
#  Subroutine('mpp_global_sum_ad_i8_3d'),
#  Subroutine('mpp_global_sum_ad_i8_4d'),
#  Subroutine('mpp_global_sum_ad_i8_5d'),
#  Subroutine('mpp_global_sum_ad_i4_2d'),
#  Subroutine('mpp_global_sum_ad_i4_3d'),
#  Subroutine('mpp_global_sum_ad_i4_4d'),
#  Subroutine('mpp_global_sum_ad_i4_5d'),
#  Subroutine('mpp_define_unstruct_domain'),
#  Subroutine('mpp_get_ug_global_domain'),
#  Subroutine('mpp_get_ug_domain_tile_pe_inf'),
#  Subroutine('mpp_deallocate_domainug'),
#  Subroutine('mosaic_init'),
#  Subroutine('initialize_diagnostic_columns'),
#  Subroutine('column_diagnostics_header'),
#  Subroutine('close_column_diagnostics_units'),
#  Subroutine('get_amip_sst'),
#  Subroutine('get_amip_ice'),
#  Subroutine('amip_interp_del'),
#  Subroutine('get_sst_grid_size'),
#  Subroutine('get_sst_grid_boundary'),
#  Subroutine('print_dates'),
#  Subroutine('amip_interp_type_eq'),
#  Subroutine('horiz_interp_spherical_wght'),
#  Subroutine('initialize_output_arrays'),
#  Subroutine('fill_xy'),
#  Subroutine('get_grid_comp_area_ug'),
#  Subroutine('get_grid_cell_centers_1d'),
#  Subroutine('get_grid_cell_centers_ug'),
#  Subroutine('define_cube_mosaic'),
#  Subroutine('xgrid_init'),
#  Subroutine('get_ocean_model_area_elements'),
#  Subroutine('setup_xmap'),
#  Subroutine('set_frac_area_sg'),
#  Subroutine('set_frac_area_ug'),
#  Subroutine('some'),
#  Subroutine('get_xmap_grid_area'),
#  Subroutine('get_index_range'),
#  Subroutine('stock_move_3d'),
#  Subroutine('stock_move_2d'),
#  Subroutine('stock_move_ug_3d'),
#  Subroutine('stock_integrate_2d'),
#  Subroutine('stock_print'),
#  Subroutine('register_tracers'),
#  Subroutine('get_tracer_indices'),
#  Subroutine('tracer_manager_end'),
#  Subroutine('get_tracer_names'),
#  Subroutine('set_tracer_profile'),
#  Subroutine('set_tracer_atts'),
#  Subroutine('set_tracer_method'),
#  Subroutine('mpp_array_global_min_max'),
#  Subroutine('set_diag_global_att'),
#  Subroutine('coupler_types_init'),
#  Subroutine('coupler_type_copy_1d_2d'),
#  Subroutine('coupler_type_copy_1d_3d'),
#  Subroutine('coupler_type_copy_2d_2d'),
#  Subroutine('coupler_type_copy_2d_3d'),
#  Subroutine('coupler_type_copy_3d_2d'),
#  Subroutine('coupler_type_copy_3d_3d'),
#  Subroutine('ct_register_restarts_2d'),
#  Subroutine('ct_register_restarts_3d'),
#  Subroutine('ct_restore_state_2d'),
#  Subroutine('ct_restore_state_3d'),
#  Subroutine('mpp_io_ct_register_restarts_2d'),
#  Subroutine('mpp_io_ct_register_restarts_to_file_2d'),
#  Subroutine('mpp_io_ct_register_restarts_3d'),
#  Subroutine('mpp_io_ct_register_restarts_to_file_3d'),
#  Subroutine('mpp_io_ct_restore_state_2d'),
#  Subroutine('mpp_io_ct_restore_state_3d'),
#  Subroutine('unstructured_write_restart'),
#  Subroutine('mpp_reset_efp_overflow_error'),
#  Subroutine('mpp_efp_assign'),
#  Subroutine('mpp_efp_list_sum_across_pes'),
#  Subroutine('register_unlimited_compressed_axis'),
#  Subroutine('compressed_start_and_count'),
#  Subroutine('netcdf_save_restart_wrap'),
#  Subroutine('read_restart_bc'),
#  Subroutine('write_restart_bc'),
#  Subroutine('mpp_record_time_start'),
#  Subroutine('mpp_record_time_end'),
#  Subroutine('drifters_core_copy_new'),
#  Subroutine('drifters_core_set_ids'),
#  Subroutine('drifters_core_print'),
#  Subroutine('time_assignment'),
#  Subroutine('gaussian_topog_init'),
#  Subroutine('get_time_axis'),
#  Subroutine('time_interp_external_exit'),
#  Subroutine('data_override_ug_1d'),
#  Subroutine('data_override_ug_2d'),
#  Subroutine('horiz_interp_type_eq'),
#  Subroutine('initialize_outfield_index_type'),
#  Subroutine('initialize_outfield_imp'),
#  Subroutine('initialize_for_ut'),
#  Subroutine('reset_time_reduction_ut'),
#  Subroutine('interpolate_type_eq'),
#  Subroutine('interpolator_init'),
#  Subroutine('init_clim_diag'),
#  Subroutine('obtain_interpolator_time_slices'),
#  Subroutine('unset_interpolator_time_flag'),
#  Subroutine('interpolator_4d'),
#  Subroutine('interpolator_3d'),
#  Subroutine('interpolator_2d'),
#  Subroutine('interpolator_4d_no_time_axis'),
#  Subroutine('interpolator_3d_no_time_axis'),
#  Subroutine('interpolator_2d_no_time_axis'),
#  Subroutine('interpolator_end'),
#  Subroutine('query_interpolator'),
#  Subroutine('get_compute_domain_dimension_indices'),
#  Subroutine('get_mosaic_tile_grid'),
#  Subroutine('mpp_memuse_begin'),
#  Subroutine('mpp_memuse_end'),
#  Subroutine('cld_ntrp_contract_indices'),
#  Subroutine('mpp_get_time_axis'),
#  Subroutine('mpp_flush'),
#  Subroutine('mpp_write_axis_data'),
#  Subroutine('mpp_copy_meta_global'),
#  Subroutine('mpp_copy_meta_axis'),
#  Subroutine('mpp_copy_meta_field'),
#  Subroutine('fillin_fieldtype'),
#  Subroutine('tri_invert'),
#  Subroutine('close_tridiagonal'),
#  Subroutine('time_interp_external_init'),
#  Subroutine('time_interp_external_2d'),
#  Subroutine('time_interp_external_0d'),
#  Subroutine('reset_src_data_region'),
#  Subroutine('set_override_region'),
#  Subroutine('get_time_axis'),
#  Subroutine('time_interp_external_exit'),
#  Subroutine('calc_cubic_grid_info'),
#  Subroutine('fm_util_start_namelist'),
#  Subroutine('fm_util_end_namelist'),
#  Subroutine('drifters_input_copy_new'),
#  Subroutine('drifters_input_save'),
#  Subroutine('error_handler'),
#  Subroutine('mosaic_init'),
#  Subroutine('fms_affinity_set'),
#  Subroutine('define_blocks'),
#  Subroutine('define_blocks_packed'),
#  Subroutine('horiz_interp_end'),
#  Subroutine('get_restart_io_mode'),
#  Subroutine('fms_io_exit'),
#  Subroutine('write_data_i3d_new'),
#  Subroutine('write_data_i2d_new'),
#  Subroutine('write_data_i1d_new'),
#  Subroutine('write_data_iscalar_new'),
#  Subroutine('register_restart_axis_r1d'),
#  Subroutine('register_restart_axis_i1d'),
#  Subroutine('register_restart_axis_unlimited'),
#  Subroutine('free_restart_type'),
#  Subroutine('set_meta_global'),
#  Subroutine('save_restart'),
#  Subroutine('save_restart_border'),
#  Subroutine('restore_state_border'),
#  Subroutine('write_data_4d_new'),
#  Subroutine('get_field_size'),
#  Subroutine('write_data_2d'),
#  Subroutine('write_ldata_2d'),
#  Subroutine('write_idata_2d'),
#  Subroutine('write_data_3d'),
#  Subroutine('write_data_4d'),
#  Subroutine('reset_field_name'),
#  Subroutine('reset_field_pointer_r0d'),
#  Subroutine('reset_field_pointer_r1d'),
#  Subroutine('reset_field_pointer_r2d'),
#  Subroutine('reset_field_pointer_r3d'),
#  Subroutine('reset_field_pointer_r4d'),
#  Subroutine('reset_field_pointer_i0d'),
#  Subroutine('reset_field_pointer_i1d'),
#  Subroutine('reset_field_pointer_i2d'),
#  Subroutine('reset_field_pointer_i3d'),
#  Subroutine('reset_field_pointer_r0d_2level'),
#  Subroutine('reset_field_pointer_r1d_2level'),
#  Subroutine('reset_field_pointer_r2d_2level'),
#  Subroutine('reset_field_pointer_r3d_2level'),
#  Subroutine('reset_field_pointer_i0d_2level'),
#  Subroutine('reset_field_pointer_i1d_2level'),
#  Subroutine('reset_field_pointer_i2d_2level'),
#  Subroutine('reset_field_pointer_i3d_2level'),
#  Subroutine('set_initialized_id'),
#  Subroutine('set_initialized_name'),
#  Subroutine('set_initialized_r2d'),
#  Subroutine('set_initialized_r3d'),
#  Subroutine('set_initialized_r4d'),
#  Subroutine('set_domain'),
#  Subroutine('nullify_domain'),
#  Subroutine('return_domain'),
#  Subroutine('get_domain_decomp'),
#  Subroutine('get_tile_string'),
#  Subroutine('get_mosaic_tile_grid'),
#  Subroutine('get_var_att_value_text'),
#  Subroutine('get_filename_appendix'),
#  Subroutine('nullify_filename_appendix'),
#  Subroutine('parse_mask_table_2d'),
#  Subroutine('parse_mask_table_3d'),
#  Subroutine('fms_io_unstructured_register_restart_axis_r1d'),
#  Subroutine('fms_io_unstructured_register_restart_axis_i1d'),
#  Subroutine('fms_io_unstructured_register_restart_axis_u'),
#  Subroutine('fms_io_unstructured_save_restart'),
#  Subroutine('fms_io_unstructured_read_r_scalar'),
#  Subroutine('fms_io_unstructured_read_r_3d'),
#  Subroutine('fms_io_unstructured_read_i_scalar'),
#  Subroutine('fms_io_unstructured_read_i_1d'),
#  Subroutine('fms_io_unstructured_read_i_2d'),
#  Subroutine('fms_io_unstructured_get_field_size'),
#  Subroutine('stocks_report_init'),
#  Subroutine('stocks_report'),
#  Subroutine('initialize'),
#  Subroutine('copy'),
#  Subroutine('netcdf_save_restart_wrap2'),
#  Subroutine('netcdf_restore_state_wrap'),
#  Subroutine('save_domain_restart_wrap'),
#  Subroutine('restore_domain_state_wrap'),
#  Subroutine('unstructured_write_restart_wrap'),
#  Subroutine('lookup_es_0d'),
#  Subroutine('lookup_es_1d'),
#  Subroutine('lookup_es_2d'),
#  Subroutine('lookup_es_3d'),
#  Subroutine('lookup_es2_0d'),
#  Subroutine('lookup_es2_1d'),
#  Subroutine('lookup_es2_2d'),
#  Subroutine('lookup_es2_3d'),
#  Subroutine('lookup_es3_0d'),
#  Subroutine('lookup_es3_1d'),
#  Subroutine('lookup_es3_2d'),
#  Subroutine('lookup_es3_3d'),
#  Subroutine('lookup_des_0d'),
#  Subroutine('lookup_des_1d'),
#  Subroutine('lookup_des_2d'),
#  Subroutine('lookup_des_3d'),
#  Subroutine('lookup_des2_0d'),
#  Subroutine('lookup_des2_1d'),
#  Subroutine('lookup_des2_2d'),
#  Subroutine('lookup_des2_3d'),
#  Subroutine('lookup_des3_0d'),
#  Subroutine('lookup_des3_1d'),
#  Subroutine('lookup_des3_2d'),
#  Subroutine('lookup_des3_3d'),
#  Subroutine('lookup_es_des_0d'),
#  Subroutine('lookup_es_des_1d'),
#  Subroutine('lookup_es_des_2d'),
#  Subroutine('lookup_es_des_3d'),
#  Subroutine('lookup_es2_des2_0d'),
#  Subroutine('lookup_es2_des2_1d'),
#  Subroutine('lookup_es2_des2_2d'),
#  Subroutine('lookup_es2_des2_3d'),
#  Subroutine('lookup_es3_des3_0d'),
#  Subroutine('lookup_es3_des3_1d'),
#  Subroutine('lookup_es3_des3_2d'),
#  Subroutine('lookup_es3_des3_3d'),
#  Subroutine('compute_qs_0d'),
#  Subroutine('compute_qs_1d'),
#  Subroutine('compute_qs_2d'),
#  Subroutine('compute_qs_3d'),
#  Subroutine('compute_mrs_0d'),
#  Subroutine('compute_mrs_1d'),
#  Subroutine('compute_mrs_2d'),
#  Subroutine('compute_mrs_3d'),
#  Subroutine('sat_vapor_pres_init'),
#  Subroutine('get_axis_bounds'),
#  Subroutine('tranlon'),
#  Subroutine('interp_1d_1d'),
#  Subroutine('interp_1d_2d'),
#  Subroutine('interp_1d_3d'),
#  Function('fm_change_root'),
#  Function('set_list_stuff'),
#  Function('mpp_pset_root'),
#  Function('mpp_pset_numroots'),
#  Function('fms_find_unique'),
#  Function('fms_array_to_pointer'),
#  Function('fms_pointer_to_array'),
#  Function('fms_find_my_string'),
#  Function('stringify_3d_r4'),
#  Function('stringify_3d_r8'),
#  Function('frac_index'),
#  Function('getrandompositiveint'),
#  Function('rad2deg'),
#  Function('get_imin'),
#  Function('get_imax'),
#  Function('get_jmin'),
#  Function('get_jmax'),
#  Function('get_kmin'),
#  Function('get_kmax'),
#  Function('send_tile_averaged_data1d'),
#  Function('send_tile_averaged_data2d'),
#  Function('send_tile_averaged_data3d'),
#  Function('need_data'),
#  Function('is_in_list'),
#  Function('mpp_get_nest_coarse_domain'),
#  Function('mpp_get_nest_fine_domain'),
#  Function('mpp_get_nest_npes'),
#  Function('mpp_get_nest_fine_npes'),
#  Function('mpp_is_nest_fine'),
#  Function('mpp_is_nest_coarse'),
#  Function('mpp_domain1d_eq'),
#  Function('mpp_domain1d_ne'),
#  Function('mpp_domain2d_eq'),
#  Function('mpp_domain2d_ne'),
#  Function('mpp_get_domain_pe'),
#  Function('mpp_get_domain_tile_root_pe'),
#  Function('mpp_get_num_overlap'),
#  Function('mpp_group_update_is_set'),
#  Function('mpp_global_field_init_comm'),
#  Function('mpp_mosaic_defined'),
#  Function('mpp_global_max_r8_2d'),
#  Function('mpp_global_max_r8_4d'),
#  Function('mpp_global_max_r8_5d'),
#  Function('mpp_global_min_r8_2d'),
#  Function('mpp_global_min_r8_4d'),
#  Function('mpp_global_min_r8_5d'),
#  Function('mpp_global_max_r4_2d'),
#  Function('mpp_global_max_r4_4d'),
#  Function('mpp_global_max_r4_5d'),
#  Function('mpp_global_min_r4_2d'),
#  Function('mpp_global_min_r4_4d'),
#  Function('mpp_global_min_r4_5d'),
#  Function('mpp_global_max_i8_2d'),
#  Function('mpp_global_max_i8_4d'),
#  Function('mpp_global_max_i8_5d'),
#  Function('mpp_global_min_i8_2d'),
#  Function('mpp_global_min_i8_4d'),
#  Function('mpp_global_min_i8_5d'),
#  Function('mpp_global_max_i4_2d'),
#  Function('mpp_global_max_i4_4d'),
#  Function('mpp_global_max_i4_5d'),
#  Function('mpp_global_min_i4_2d'),
#  Function('mpp_global_min_i4_4d'),
#  Function('mpp_global_min_i4_5d'),
#  Function('mpp_domainug_eq'),
#  Function('mpp_domainug_ne'),
#  Function('is_inside_polygon'),
#  Function('amip_interp_new_1d'),
#  Function('amip_interp_new_2d'),
#  Function('date_equals'),
#  Function('date_not_equals'),
#  Function('date_gt'),
#  Function('xgrid_count'),
#  Function('get_tracer_name'),
#  Function('adjust_mass'),
#  Function('adjust_positive_def'),
#  Function('mpp_query_efp_overflow_error'),
#  Function('mpp_efp_plus'),
#  Function('mpp_efp_minus'),
#  Function('mpp_efp_real_diff'),
#  Function('mpp_real_to_efp'),
#  Function('is_registered_to_restart'),
#  Function('mpp_error_state'),
#  Function('get_unit'),
#  Function('find_bin'),
#  Function('get_ascii_file_num_lines'),
#  Function('time_ge'),
#  Function('time_le'),
#  Function('time_ne'),
#  Function('time_plus'),
#  Function('time_minus'),
#  Function('scalar_time_mult'),
#  Function('time_divide'),
#  Function('time_real_divide'),
#  Function('real_to_time_type'),
#  Function('time_scalar_divide'),
#  Function('interval_alarm'),
#  Function('repeat_alarm'),
#  Function('decrement_date'),
#  Function('day_of_year'),
#  Function('lowerb_comp'),
#  Function('upperb_comp'),
#  Function('a_lessthan_b'),
#  Function('a_greaterthan_b'),
#  Function('a_noteq_b'),
#  Function('get_module_name'),
#  Function('get_field_name'),
#  Function('get_output_name'),
#  Function('get_output_file'),
#  Function('get_pow_value'),
#  Function('get_phys_window'),
#  Function('get_need_compute'),
#  Function('get_reduced_k_range'),
#  Function('get_missvalue_present'),
#  Function('get_mask_variant'),
#  Function('get_mask_present'),
#  Function('get_time_reduction'),
#  Function('get_f1'),
#  Function('get_f2'),
#  Function('get_f3'),
#  Function('get_f4'),
#  Function('get_is'),
#  Function('get_js'),
#  Function('get_ks'),
#  Function('get_ie'),
#  Function('get_je'),
#  Function('get_ke'),
#  Function('get_hi'),
#  Function('get_hj'),
#  Function('string_array_index'),
#  Function('monotonic_array'),
#  Function('constructseed'),
#  Function('getpeakrss'),
#  Function('mpp_get_default_calendar'),
#  Function('mpp_get_field_index'),
#  Function('mpp_get_axis_index'),
#  Function('mpp_get_axis_by_name'),
#  Function('mpp_get_axis_length'),
#  Function('mpp_get_recdimid'),
#  Function('mpp_get_ncid'),
#  Function('mpp_get_axis_id'),
#  Function('mpp_get_field_id'),
#  Function('mpp_get_att_type'),
#  Function('mpp_get_att_real'),
#  Function('mpp_get_field_name'),
#  Function('mpp_io_clock_on'),
#  Function('mpp_get_maxunits'),
#  Function('do_cf_compliance'),
#  Function('init_external_field'),
#  Function('get_external_field_missing'),
#  Function('fm_util_get_index_list'),
#  Function('fm_util_get_integer_array'),
#  Function('get_topog_mean_1d'),
#  Function('get_topog_mean_2d'),
#  Function('get_topog_stdev_1d'),
#  Function('get_topog_stdev_2d'),
#  Function('get_ocean_mask_1d'),
#  Function('get_ocean_mask_2d'),
#  Function('get_water_mask_1d'),
#  Function('get_water_mask_2d'),
#  Function('month_midpt'),
#  Function('is_inside_polygon'),
#  Function('fms_affinity_get'),
#  Function('lookup_field_r'),
#  Function('lookup_axis'),
#  Function('open_restart_file'),
#  Function('open_direct_file'),
#  Function('open_file'),
#  Function('fms_io_unstructured_register_restart_field_r_0d'),
#  Function('fms_io_unstructured_register_restart_field_r_1d'),
#  Function('fms_io_unstructured_register_restart_field_r_2d'),
#  Function('fms_io_unstructured_register_restart_field_r_3d'),
#  Function('fms_io_unstructured_register_restart_field_i_0d'),
#  Function('fms_io_unstructured_register_restart_field_i_1d'),
#  Function('fms_io_unstructured_register_restart_field_i_2d'),
#  Function('fms_io_unstructured_field_exist'),
#  Function('fmsdiagtimereduction_type_constructor'),
#  Function('has_time_ops_imp'),
#  Function('do_time_averaging_imp'),
#  Function('is_time_average_imp'),
#  Function('is_time_none_imp'),
#  Function('is_time_rms_imp'),
#  Function('is_time_max_imp'),
#  Function('is_time_min_imp'),
#  Function('is_time_sum_imp'),
#  Function('is_time_diurnal_imp'),
#  Function('is_time_power_imp'),
#  Function('create_diskless_netcdf_file_wrap'),
#  Function('create_diskless_domain_file'),
#  Function('create_diskless_unstructured_domain_file'),
#  Function('get_axis_fold'),
#  Function('frac_index')]

# %%
#group unnecessary subroutines by modules they belong to:
from collections import defaultdict
unnecessary_subroutines_by_module = defaultdict(list)
for subroutine in fms_subroutines_NOT_needed_by_mom6:
    module_path = subroutine.program_unit.parse_tree_path
    source_path = path_names.get(module_path.stem.lower(),'')
    unnecessary_subroutines_by_module[source_path].append(subroutine)

# %%
# sort modules by ratio of unnecessary subroutines to total subroutines
module_unnecessary_ratio = []
for module_path, subroutines in unnecessary_subroutines_by_module.items():
    total_subroutines = [r for r in all_fms_routines if path_names.get(r.program_unit.parse_tree_path.stem.lower(),'') == module_path]
    ratio = len(subroutines) / len(total_subroutines)
    module_unnecessary_ratio.append((module_path, ratio, len(subroutines), len(total_subroutines)))

module_unnecessary_ratio.sort(key=lambda x: x[1], reverse=True)
for module in module_unnecessary_ratio[:30]:
    print(f"Module: {module[0]}, Unnecessary Ratio: {module[1]:.2f}, Unnecessary Count: {module[2]}, Total Count: {module[3]}")
# Out:
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_pset.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 28, Total Count: 28
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 21, Total Count: 21
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters_comm.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 8, Total Count: 8
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/monin_obukhov/monin_obukhov.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 26, Total Count: 26
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mosaic/grid.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 18, Total Count: 18
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/diag_manager/fms_diag_bbox.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 10, Total Count: 10
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/diag_integral/diag_integral.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 17, Total Count: 17
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/constants4/fmsconstantsr4.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 1, Total Count: 1
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/column_diagnostics/column_diagnostics.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 4, Total Count: 4
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/amip_interp/amip_interp.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 20, Total Count: 20
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/monin_obukhov/monin_obukhov_inter.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 9, Total Count: 9
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/exchange/xgrid.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 60, Total Count: 60
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/tracer_manager/tracer_manager.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 21, Total Count: 21
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_utilities.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 1, Total Count: 1
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_efp.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 19, Total Count: 19
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters_io.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 8, Total Count: 8
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters_core.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 8, Total Count: 8
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/topography/gaussian_topog.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 3, Total Count: 3
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/diag_manager/fms_diag_outfield.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 29, Total Count: 29
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/interpolator/interpolator.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 28, Total Count: 28
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/cloud_interpolator.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 6, Total Count: 6
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/tridiagonal/tridiagonal.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 2, Total Count: 2
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/time_interp/time_interp_external.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 18, Total Count: 18
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mosaic/gradient.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 2, Total Count: 2
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters_input.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 4, Total Count: 4
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/topography/topography.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 23, Total Count: 23
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mosaic/mosaic.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 12, Total Count: 12
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/affinity/fms_affinity.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 5, Total Count: 5
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/block_control/block_control.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 2, Total Count: 2
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/constants/fmsconstants.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 1, Total Count: 1

# %%
# sort modules by ratio of unnecessary subroutines to total subroutines
module_unnecessary_ratio = []
for module_path, subroutines in unnecessary_subroutines_by_module.items():
    total_subroutines = [r for r in all_fms_routines if path_names.get(r.program_unit.parse_tree_path.stem.lower(),'') == module_path]
    ratio = len(subroutines) / len(total_subroutines)
    module_unnecessary_ratio.append((module_path, ratio, len(subroutines), len(total_subroutines)))

module_unnecessary_ratio.sort(key=lambda x: x[1], reverse=True)
for module in module_unnecessary_ratio[:30]:
    print(f"Module: {module[0]}, Unnecessary Ratio: {module[1]:.2f}, Unnecessary Count: {module[2]}, Total Count: {module[3]}")
# Out:
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_pset.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 28, Total Count: 28
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 21, Total Count: 21
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters_comm.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 8, Total Count: 8
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/monin_obukhov/monin_obukhov.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 26, Total Count: 26
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mosaic/grid.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 18, Total Count: 18
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/diag_manager/fms_diag_bbox.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 10, Total Count: 10
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/diag_integral/diag_integral.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 17, Total Count: 17
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/constants4/fmsconstantsr4.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 1, Total Count: 1
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/column_diagnostics/column_diagnostics.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 4, Total Count: 4
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/amip_interp/amip_interp.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 20, Total Count: 20
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/monin_obukhov/monin_obukhov_inter.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 9, Total Count: 9
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/exchange/xgrid.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 60, Total Count: 60
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/tracer_manager/tracer_manager.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 21, Total Count: 21
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_utilities.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 1, Total Count: 1
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_efp.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 19, Total Count: 19
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters_io.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 8, Total Count: 8
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters_core.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 8, Total Count: 8
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/topography/gaussian_topog.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 3, Total Count: 3
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/diag_manager/fms_diag_outfield.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 29, Total Count: 29
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/interpolator/interpolator.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 28, Total Count: 28
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/cloud_interpolator.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 6, Total Count: 6
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/tridiagonal/tridiagonal.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 2, Total Count: 2
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/time_interp/time_interp_external.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 18, Total Count: 18
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mosaic/gradient.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 2, Total Count: 2
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters_input.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 4, Total Count: 4
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/topography/topography.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 23, Total Count: 23
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mosaic/mosaic.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 12, Total Count: 12
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/affinity/fms_affinity.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 5, Total Count: 5
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/block_control/block_control.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 2, Total Count: 2
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/constants/fmsconstants.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 1, Total Count: 1

# %%
# sort modules by ratio of unnecessary subroutines to total subroutines
module_unnecessary_ratio = []
for module_path, subroutines in unnecessary_subroutines_by_module.items():
    total_subroutines = [r for r in all_fms_routines if path_names.get(r.program_unit.parse_tree_path.stem.lower(),'') == module_path]
    ratio = len(subroutines) / len(total_subroutines)
    module_unnecessary_ratio.append((module_path, ratio, len(subroutines), len(total_subroutines)))

module_unnecessary_ratio.sort(key=lambda x: x[2], reverse=True)
for module in module_unnecessary_ratio[:30]:
    print(f"Module: {module[0]}, Unnecessary Ratio: {module[1]:.2f}, Unnecessary Count: {module[2]}, Total Count: {module[3]}")
# Out:
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_domains.F90, Unnecessary Ratio: 0.49, Unnecessary Count: 338, Total Count: 686
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/fms/fms_io.F90, Unnecessary Ratio: 0.80, Unnecessary Count: 148, Total Count: 186
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_io.F90, Unnecessary Ratio: 0.63, Unnecessary Count: 101, Total Count: 161
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/exchange/xgrid.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 60, Total Count: 60
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/sat_vapor_pres/sat_vapor_pres_k.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 59, Total Count: 59
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/sat_vapor_pres/sat_vapor_pres.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 56, Total Count: 56
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/fms2_io/netcdf_io.F90, Unnecessary Ratio: 0.26, Unnecessary Count: 32, Total Count: 124
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp.F90, Unnecessary Ratio: 0.08, Unnecessary Count: 31, Total Count: 377
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/field_manager/field_manager.F90, Unnecessary Ratio: 0.50, Unnecessary Count: 30, Total Count: 60
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/time_manager/time_manager.F90, Unnecessary Ratio: 0.35, Unnecessary Count: 30, Total Count: 85
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/diag_manager/fms_diag_outfield.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 29, Total Count: 29
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_pset.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 28, Total Count: 28
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/interpolator/interpolator.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 28, Total Count: 28
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/monin_obukhov/monin_obukhov.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 26, Total Count: 26
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/topography/topography.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 23, Total Count: 23
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/drifters/drifters.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 21, Total Count: 21
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/tracer_manager/tracer_manager.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 21, Total Count: 21
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/amip_interp/amip_interp.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 20, Total Count: 20
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/coupler/coupler_types.F90, Unnecessary Ratio: 0.29, Unnecessary Count: 20, Total Count: 69
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/string_utils/fms_string_utils.F90, Unnecessary Ratio: 0.90, Unnecessary Count: 19, Total Count: 21
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mosaic2/grid2.F90, Unnecessary Ratio: 0.68, Unnecessary Count: 19, Total Count: 28
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mpp/mpp_efp.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 19, Total Count: 19
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/mosaic/grid.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 18, Total Count: 18
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/time_interp/time_interp_external.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 18, Total Count: 18
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/diag_integral/diag_integral.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 17, Total Count: 17
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/fms2_io/blackboxio.F90, Unnecessary Ratio: 0.94, Unnecessary Count: 15, Total Count: 16
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/axis_utils/axis_utils.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 15, Total Count: 15
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/astronomy/astronomy.F90, Unnecessary Ratio: 0.37, Unnecessary Count: 14, Total Count: 38
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/fms2_io/fms_netcdf_domain_io.F90, Unnecessary Ratio: 0.35, Unnecessary Count: 14, Total Count: 40
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/FMS/diag_manager/fms_diag_time_reduction.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 13, Total Count: 13
