# %%
import networkx as nx
from pathlib import Path

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from flinspect.parse_tree import ParseTree
from flinspect.parse_forest import ParseForest

# %%
build_dirs = [
    "/glade/work/altuntas/turbo-stack/bin/flang_ptree/TIM/",
    "/glade/work/altuntas/turbo-stack/bin/flang_ptree/MOM6-infra",
    "/glade/work/altuntas/turbo-stack/bin/flang_ptree/MOM6"
]

parse_tree_paths = [f for dir in build_dirs for f in Path(dir).glob("*_ptree")]

# %%
pf = ParseForest(parse_tree_paths)
# Out:
# Warning: Skipping mpp_memuse.o_ptree as it does not start with proper header.
# Warning: Skipping fms_string_utils_binding.o_ptree as it does not start with proper header.
# Warning: Skipping mppnccombine.o_ptree as it does not start with proper header.
# Warning: Skipping mosaic_util.o_ptree as it does not start with proper header.
# Warning: Skipping gradient_c2l.o_ptree as it does not start with proper header.
# Warning: Skipping affinity.o_ptree as it does not start with proper header.
# Warning: Skipping interp.o_ptree as it does not start with proper header.
# Warning: Skipping read_mosaic.o_ptree as it does not start with proper header.
# Warning: Skipping create_xgrid.o_ptree as it does not start with proper header.

# %%
nr = pf.registry

# %% [markdown]
# # Module Dependency Analysis

# %%
G = pf.get_module_dependency_graph()
# Out:
# Skipped 8 modules with unknown parse tree paths: ['netcdf', 'iso_c_binding', 'iso_fortran_env', 'mpi', 'netcdf_nf_data', 'netcdf_nf_interfaces', 'netcdf4_nf_interfaces', 'omp_lib']

# %%
# Determine source paths via the path_names files in build dirs
# This will be used to color nodes and edges based on where modules are located
path_names = {}
for build_dir in build_dirs:
    path_names_file = Path(build_dir)/"path_names"
    with open(path_names_file) as f:
        for line in f:
            src_file_path = Path(line.strip())
            path_names[src_file_path.stem.lower()] = src_file_path.as_posix()

# %%
# Find all nodes where /TIM/ is in the source path
tim_nodes = [node for node in G.nodes() if "/TIM/" in path_names.get(G.nodes[node].get('source_name','').lower(),'')]

# %%
# Find all tim_nodes that have no incoming edges (i.e., no dependencies)
tim_root_nodes = [node for node in tim_nodes if G.in_degree(node) == 0]

for tim_root_node in tim_root_nodes:
    print(tim_root_node, path_names.get(G.nodes[tim_root_node].get('source_name','').lower(),''))
# Out:
# fms /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/libFMS.F90

# %%
# Find all TIM nodes that is not needed by any other TIM nodes
tim_leaf_nodes = [node for node in tim_nodes if G.out_degree(node) == 0]

for tim_leaf_node in tim_leaf_nodes:
    print(tim_leaf_node, path_names.get(G.nodes[tim_leaf_node].get('source_name','').lower(),''))
# Out:
# platform_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/platform/platform.F90
# mersennetwister_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/random_numbers/mersennetwister.F90

# %%
# Find all MOM6 nodes:
mom6_nodes = [node for node in G.nodes() if "/MOM6/" in path_names.get(G.nodes[node].get('source_name','').lower(),'')]

# Find all TIM nodes that is not needed by any other MOM6 nodes recursively (i.e. transitive closure)
mom6_deps = set()
for mom6_node in mom6_nodes:
    mom6_deps.update(nx.descendants(G, mom6_node))

# Find all TIM nodes that are not needed by any other MOM6 nodes
tim_leaf_nodes = [node for node in tim_nodes if all(pred not in mom6_deps for pred in G.predecessors(node))]

for tim_leaf_node in tim_leaf_nodes:
    print(tim_leaf_node, path_names.get(G.nodes[tim_leaf_node].get('source_name','').lower(),''))
# Out:
# fms /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/libFMS.F90
# block_control_mod /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/block_control/block_control.F90

# %% [markdown]
# # Call Graph Analysis

# %%
path_names = {}
for build_dir in build_dirs:
    path_names_file = Path(build_dir)/"path_names"
    with open(path_names_file) as f:
        for line in f:
            src_file_path = Path(line.strip())
            path_names[src_file_path.stem.lower()] = src_file_path.as_posix()

# %%
gsc = pf.get_call_graph()
# Out:
# Warning: Skipping mpp_memuse.o_ptree as it does not start with proper header.
# Warning: Skipping fms_string_utils_binding.o_ptree as it does not start with proper header.
# Warning: Skipping mppnccombine.o_ptree as it does not start with proper header.
# Warning: Skipping mosaic_util.o_ptree as it does not start with proper header.
# Warning: Skipping gradient_c2l.o_ptree as it does not start with proper header.
# Warning: Skipping affinity.o_ptree as it does not start with proper header.
# Warning: Skipping interp.o_ptree as it does not start with proper header.
# Warning: Skipping read_mosaic.o_ptree as it does not start with proper header.
# Warning: Skipping create_xgrid.o_ptree as it does not start with proper header.
# Warning: Skipping mpp_memuse.o_ptree as it does not start with proper header.
# Warning: Skipping fms_string_utils_binding.o_ptree as it does not start with proper header.
# Warning: Skipping mppnccombine.o_ptree as it does not start with proper header.
# Warning: Skipping mosaic_util.o_ptree as it does not start with proper header.
# Warning: Skipping gradient_c2l.o_ptree as it does not start with proper header.
# Warning: Skipping affinity.o_ptree as it does not start with proper header.
# Warning: Skipping interp.o_ptree as it does not start with proper header.
# Warning: Skipping read_mosaic.o_ptree as it does not start with proper header.
# Warning: Skipping create_xgrid.o_ptree as it does not start with proper header.
# Total unfound calls across all parse trees: 174
# Total unfound function calls across all parse trees: 70403

# %%
# Find all TIM subroutines and MOM6 subroutines
all_tim_routines = []
all_mom6_routines = []
for node in gsc.nodes():
    try:
        module_path = node.program_unit.parse_tree_path
        source_path = path_names.get(module_path.stem.lower(),'')
    except AttributeError:
        continue
    if "/MOM6/" in source_path:
        all_mom6_routines.append(node)
    elif "/TIM/" in source_path:
        all_tim_routines.append(node)

# %%
len(all_mom6_routines), len(all_tim_routines)
# Out:
# (3525, 2086)

# %%
def get_tim_subroutines_needed_by_mom6(gsc, all_mom6_routines):
    tim_subroutines_needed_by_mom6 = set()
    for mom6_routine in all_mom6_routines:
        descendants = nx.descendants(gsc, mom6_routine)
        for desc in descendants:
            try:
                module_path = desc.program_unit.parse_tree_path
                source_path = path_names.get(module_path.stem.lower(),'')
            except AttributeError:
                continue
            if "/TIM/" in source_path:
                tim_subroutines_needed_by_mom6.add(desc)
    return tim_subroutines_needed_by_mom6

# %%
tim_subroutines_needed_by_mom6 = get_tim_subroutines_needed_by_mom6(gsc, all_mom6_routines)

# %%
len(tim_subroutines_needed_by_mom6)
# Out:
# 1667

# %%
tim_subroutines_NOT_needed_by_mom6 = [r for r in all_tim_routines if r not in tim_subroutines_needed_by_mom6]
len(tim_subroutines_NOT_needed_by_mom6)
# Out:
# 648

# %%
# find all TIM subroutines that are not needed by MOM6 and are not called by any other TIM subroutines
tim_subroutines_NOT_needed_by_mom6_and_not_called_by_tim = []
for routine in tim_subroutines_NOT_needed_by_mom6:
    callers = list(gsc.predecessors(routine))
    called_by_tim = False
    for caller in callers:
        try:
            module_path = caller.program_unit.parse_tree_path
            source_path = path_names.get(module_path.stem.lower(),'')
        except AttributeError:
            continue
        if "/TIM/" in source_path:
            called_by_tim = True
            break
    if not called_by_tim:
        tim_subroutines_NOT_needed_by_mom6_and_not_called_by_tim.append(routine)

# %%
len(tim_subroutines_NOT_needed_by_mom6_and_not_called_by_tim)
# Out:
# 342

# %%
for routine in tim_subroutines_NOT_needed_by_mom6_and_not_called_by_tim:
    #if 'fms_io' in routine.program_unit.name:
    if 'mem' in routine.name:
        print(routine.name)
# Out:
# mpp_memuse_begin
# mpp_memuse_end

# %%
tim_subroutines_NOT_needed_by_mom6_and_not_called_by_tim[10:]
# Out:
# [Subroutine('set_orbital_parameters'),
#  Subroutine('get_orbital_parameters'),
#  Subroutine('set_ref_date_of_ae'),
#  Subroutine('get_ref_date_of_ae'),
#  Subroutine('annual_mean_solar_1d'),
#  Subroutine('annual_mean_solar_2level'),
#  Subroutine('astronomy_end'),
#  Subroutine('finalize_randomnumbersequence'),
#  Subroutine('reset_bounds'),
#  Subroutine('update_bounds'),
#  Subroutine('reset_bounds_from_array_4d'),
#  Subroutine('reset_bounds_from_array_5d'),
#  Subroutine('fieldbuff_copy_missvals_3d_r4'),
#  Subroutine('fieldbuff_copy_missvals_3d_r8'),
#  Subroutine('diag_field_add_cell_measures'),
#  Subroutine('openmp_thread_trap'),
#  Subroutine('append_to_list'),
#  Subroutine('destroy_list'),
#  Subroutine('nullify_filename_appendix'),
#  Subroutine('mpp_set_super_grid_indices'),
#  Subroutine('mpp_copy_domain2d'),
#  Subroutine('mpp_clear_group_update'),
#  Subroutine('mpp_define_layout2d'),
#  Subroutine('mpp_define_mosaic'),
#  Subroutine('mpp_check_field_3d'),
#  Subroutine('mosaic_init'),
#  Subroutine('get_mosaic_contact'),
#  Subroutine('horiz_interp_spherical_wght'),
#  Subroutine('initialize_output_arrays'),
#  Subroutine('fill_xy'),
#  Subroutine('get_grid_comp_area_sg'),
#  Subroutine('get_grid_cell_centers_2d'),
#  Subroutine('coupler_types_init'),
#  Subroutine('coupler_type_copy_1d_2d'),
#  Subroutine('coupler_type_copy_1d_3d'),
#  Subroutine('coupler_type_copy_2d_2d'),
#  Subroutine('coupler_type_copy_2d_3d'),
#  Subroutine('coupler_type_copy_3d_2d'),
#  Subroutine('coupler_type_copy_3d_3d'),
#  Subroutine('ct_register_restarts_2d'),
#  Subroutine('ct_register_restarts_3d'),
#  Subroutine('ct_restore_state_2d'),
#  Subroutine('ct_restore_state_3d'),
#  Subroutine('mpp_io_ct_register_restarts_2d'),
#  Subroutine('mpp_io_ct_register_restarts_to_file_2d'),
#  Subroutine('mpp_io_ct_register_restarts_3d'),
#  Subroutine('mpp_io_ct_register_restarts_to_file_3d'),
#  Subroutine('mpp_io_ct_restore_state_2d'),
#  Subroutine('mpp_io_ct_restore_state_3d'),
#  Subroutine('register_unlimited_compressed_axis'),
#  Subroutine('netcdf_restore_state'),
#  Subroutine('compressed_start_and_count'),
#  Subroutine('netcdf_save_restart_wrap'),
#  Subroutine('read_restart_bc'),
#  Subroutine('write_restart_bc'),
#  Subroutine('mpp_record_time_start'),
#  Subroutine('mpp_record_time_end'),
#  Subroutine('time_assignment'),
#  Subroutine('get_date_julian'),
#  Subroutine('get_date_no_leap'),
#  Subroutine('get_time_axis'),
#  Subroutine('time_interp_external_exit'),
#  Subroutine('horiz_interp_type_eq'),
#  Subroutine('initialize_outfield_index_type'),
#  Subroutine('initialize_outfield_imp'),
#  Subroutine('initialize_for_ut'),
#  Subroutine('reset_time_reduction_ut'),
#  Subroutine('save_domain_restart'),
#  Subroutine('restore_domain_state'),
#  Subroutine('get_compute_domain_dimension_indices'),
#  Subroutine('get_mosaic_tile_grid'),
#  Subroutine('mpp_memuse_begin'),
#  Subroutine('mpp_memuse_end'),
#  Subroutine('mpp_get_time_axis'),
#  Subroutine('mpp_get_times'),
#  Subroutine('mpp_flush'),
#  Subroutine('mpp_get_tavg_info'),
#  Subroutine('mpp_write_axis_data'),
#  Subroutine('mpp_copy_meta_global'),
#  Subroutine('mpp_copy_meta_axis'),
#  Subroutine('mpp_copy_meta_field'),
#  Subroutine('mpp_modify_axis_meta'),
#  Subroutine('mpp_modify_field_meta'),
#  Subroutine('fillin_fieldtype'),
#  Subroutine('fm_util_start_namelist'),
#  Subroutine('fm_util_end_namelist'),
#  Subroutine('error_handler'),
#  Subroutine('fms_affinity_set'),
#  Subroutine('define_blocks'),
#  Subroutine('define_blocks_packed'),
#  Subroutine('horiz_interp_end'),
#  Subroutine('get_restart_io_mode'),
#  Subroutine('fms_io_exit'),
#  Subroutine('write_data_i3d_new'),
#  Subroutine('write_data_i2d_new'),
#  Subroutine('write_data_i1d_new'),
#  Subroutine('write_data_iscalar_new'),
#  Subroutine('register_restart_axis_r1d'),
#  Subroutine('register_restart_axis_i1d'),
#  Subroutine('register_restart_axis_unlimited'),
#  Subroutine('free_restart_type'),
#  Subroutine('set_meta_global'),
#  Subroutine('save_restart'),
#  Subroutine('save_restart_border'),
#  Subroutine('restore_state_border'),
#  Subroutine('write_data_4d_new'),
#  Subroutine('field_size'),
#  Subroutine('get_field_size'),
#  Subroutine('read_compressed_i1d'),
#  Subroutine('read_compressed_i2d'),
#  Subroutine('read_compressed_3d'),
#  Subroutine('write_data_2d'),
#  Subroutine('write_ldata_2d'),
#  Subroutine('write_idata_2d'),
#  Subroutine('write_data_3d'),
#  Subroutine('write_data_4d'),
#  Subroutine('reset_field_name'),
#  Subroutine('reset_field_pointer_r0d'),
#  Subroutine('reset_field_pointer_r1d'),
#  Subroutine('reset_field_pointer_r2d'),
#  Subroutine('reset_field_pointer_r3d'),
#  Subroutine('reset_field_pointer_r4d'),
#  Subroutine('reset_field_pointer_i0d'),
#  Subroutine('reset_field_pointer_i1d'),
#  Subroutine('reset_field_pointer_i2d'),
#  Subroutine('reset_field_pointer_i3d'),
#  Subroutine('reset_field_pointer_r0d_2level'),
#  Subroutine('reset_field_pointer_r1d_2level'),
#  Subroutine('reset_field_pointer_r2d_2level'),
#  Subroutine('reset_field_pointer_r3d_2level'),
#  Subroutine('reset_field_pointer_i0d_2level'),
#  Subroutine('reset_field_pointer_i1d_2level'),
#  Subroutine('reset_field_pointer_i2d_2level'),
#  Subroutine('reset_field_pointer_i3d_2level'),
#  Subroutine('set_initialized_id'),
#  Subroutine('set_initialized_name'),
#  Subroutine('set_initialized_r2d'),
#  Subroutine('set_initialized_r3d'),
#  Subroutine('set_initialized_r4d'),
#  Subroutine('set_domain'),
#  Subroutine('return_domain'),
#  Subroutine('get_domain_decomp'),
#  Subroutine('get_tile_string'),
#  Subroutine('get_mosaic_tile_grid'),
#  Subroutine('get_var_att_value_text'),
#  Subroutine('get_filename_appendix'),
#  Subroutine('nullify_filename_appendix'),
#  Subroutine('parse_mask_table_2d'),
#  Subroutine('parse_mask_table_3d'),
#  Subroutine('initialize'),
#  Subroutine('copy'),
#  Function('parse_real'),
#  Function('parse_integer'),
#  Function('parse_string'),
#  Function('set_list_stuff'),
#  Function('fm_modify_name'),
#  Function('fm_query_method'),
#  Function('fm_copy_list'),
#  Function('fms_find_unique'),
#  Function('fms_array_to_pointer'),
#  Function('fms_pointer_to_array'),
#  Function('fms_find_my_string'),
#  Function('stringify_3d_r4'),
#  Function('stringify_3d_r8'),
#  Function('lon_in_range'),
#  Function('frac_index'),
#  Function('getrandompositiveint'),
#  Function('get_imin'),
#  Function('get_imax'),
#  Function('get_jmin'),
#  Function('get_jmax'),
#  Function('get_kmin'),
#  Function('get_kmax'),
#  Function('send_tile_averaged_data1d'),
#  Function('send_tile_averaged_data2d'),
#  Function('send_tile_averaged_data3d'),
#  Function('get_base_time'),
#  Function('need_data'),
#  Function('is_in_list'),
#  Function('mpp_domain1d_eq'),
#  Function('mpp_domain1d_ne'),
#  Function('mpp_domain2d_eq'),
#  Function('mpp_domain2d_ne'),
#  Function('mpp_get_domain_pe'),
#  Function('mpp_get_domain_tile_root_pe'),
#  Function('mpp_domain_is_initialized'),
#  Function('mpp_get_tile_npes'),
#  Function('mpp_get_num_overlap'),
#  Function('mpp_get_domain_root_pe'),
#  Function('mpp_group_update_is_set'),
#  Function('mpp_global_field_init_comm'),
#  Function('mpp_mosaic_defined'),
#  Function('mpp_global_max_r8_2d'),
#  Function('mpp_global_max_r8_4d'),
#  Function('mpp_global_max_r8_5d'),
#  Function('mpp_global_min_r8_2d'),
#  Function('mpp_global_min_r8_4d'),
#  Function('mpp_global_min_r8_5d'),
#  Function('mpp_global_max_r4_2d'),
#  Function('mpp_global_max_r4_4d'),
#  Function('mpp_global_max_r4_5d'),
#  Function('mpp_global_min_r4_2d'),
#  Function('mpp_global_min_r4_4d'),
#  Function('mpp_global_min_r4_5d'),
#  Function('mpp_global_max_i8_2d'),
#  Function('mpp_global_max_i8_4d'),
#  Function('mpp_global_max_i8_5d'),
#  Function('mpp_global_min_i8_2d'),
#  Function('mpp_global_min_i8_4d'),
#  Function('mpp_global_min_i8_5d'),
#  Function('mpp_global_max_i4_2d'),
#  Function('mpp_global_max_i4_4d'),
#  Function('mpp_global_max_i4_5d'),
#  Function('mpp_global_min_i4_2d'),
#  Function('mpp_global_min_i4_4d'),
#  Function('mpp_global_min_i4_5d'),
#  Function('mpp_global_sum_r8_2d'),
#  Function('mpp_global_sum_r8_3d'),
#  Function('mpp_global_sum_r8_4d'),
#  Function('mpp_global_sum_r8_5d'),
#  Function('mpp_global_sum_r4_2d'),
#  Function('mpp_global_sum_r4_3d'),
#  Function('mpp_global_sum_r4_4d'),
#  Function('mpp_global_sum_r4_5d'),
#  Function('mpp_global_sum_i8_2d'),
#  Function('mpp_global_sum_i8_3d'),
#  Function('mpp_global_sum_i8_4d'),
#  Function('mpp_global_sum_i8_5d'),
#  Function('mpp_global_sum_i4_2d'),
#  Function('mpp_global_sum_i4_3d'),
#  Function('mpp_global_sum_i4_4d'),
#  Function('mpp_global_sum_i4_5d'),
#  Function('is_inside_polygon'),
#  Function('get_variable_sense'),
#  Function('is_registered_to_restart'),
#  Function('mpp_error_state'),
#  Function('get_unit'),
#  Function('find_bin'),
#  Function('get_ascii_file_num_lines'),
#  Function('time_ge'),
#  Function('time_le'),
#  Function('time_ne'),
#  Function('time_plus'),
#  Function('time_minus'),
#  Function('scalar_time_mult'),
#  Function('time_divide'),
#  Function('time_real_divide'),
#  Function('real_to_time_type'),
#  Function('time_scalar_divide'),
#  Function('interval_alarm'),
#  Function('repeat_alarm'),
#  Function('set_date_julian'),
#  Function('set_date_no_leap'),
#  Function('decrement_date'),
#  Function('day_of_year'),
#  Function('lowerb_comp'),
#  Function('upperb_comp'),
#  Function('a_lessthan_b'),
#  Function('a_greaterthan_b'),
#  Function('a_noteq_b'),
#  Function('get_module_name'),
#  Function('get_field_name'),
#  Function('get_output_name'),
#  Function('get_output_file'),
#  Function('get_pow_value'),
#  Function('get_phys_window'),
#  Function('get_need_compute'),
#  Function('get_reduced_k_range'),
#  Function('get_missvalue_present'),
#  Function('get_mask_variant'),
#  Function('get_mask_present'),
#  Function('get_time_reduction'),
#  Function('get_f1'),
#  Function('get_f2'),
#  Function('get_f3'),
#  Function('get_f4'),
#  Function('get_is'),
#  Function('get_js'),
#  Function('get_ks'),
#  Function('get_ie'),
#  Function('get_je'),
#  Function('get_ke'),
#  Function('get_hi'),
#  Function('get_hj'),
#  Function('string_array_index'),
#  Function('monotonic_array'),
#  Function('constructseed'),
#  Function('getpeakrss'),
#  Function('mpp_get_default_calendar'),
#  Function('mpp_get_field_index'),
#  Function('mpp_get_axis_index'),
#  Function('mpp_get_axis_by_name'),
#  Function('mpp_get_axis_length'),
#  Function('mpp_get_axis_bounds'),
#  Function('mpp_get_recdimid'),
#  Function('mpp_get_ncid'),
#  Function('mpp_get_axis_id'),
#  Function('mpp_get_field_id'),
#  Function('mpp_is_valid'),
#  Function('mpp_get_att_type'),
#  Function('mpp_get_att_length'),
#  Function('mpp_get_att_real'),
#  Function('mpp_get_field_name'),
#  Function('mpp_get_file_name'),
#  Function('mpp_file_is_opened'),
#  Function('mpp_io_clock_on'),
#  Function('mpp_get_maxunits'),
#  Function('do_cf_compliance'),
#  Function('fm_util_get_index_list'),
#  Function('fm_util_get_integer_array'),
#  Function('fraction_of_year'),
#  Function('month_midpt'),
#  Function('fms_affinity_get'),
#  Function('lookup_field_r'),
#  Function('lookup_axis'),
#  Function('dimension_size'),
#  Function('open_namelist_file'),
#  Function('open_restart_file'),
#  Function('open_direct_file'),
#  Function('open_file'),
#  Function('get_great_circle_algorithm'),
#  Function('fmsdiagtimereduction_type_constructor'),
#  Function('has_time_ops_imp'),
#  Function('do_time_averaging_imp'),
#  Function('is_time_average_imp'),
#  Function('is_time_none_imp'),
#  Function('is_time_rms_imp'),
#  Function('is_time_max_imp'),
#  Function('is_time_min_imp'),
#  Function('is_time_sum_imp'),
#  Function('is_time_diurnal_imp'),
#  Function('is_time_power_imp')]

# %%
#group unnecessary subroutines by modules they belong to:
from collections import defaultdict
unnecessary_subroutines_by_module = defaultdict(list)
for subroutine in tim_subroutines_NOT_needed_by_mom6:
    module_path = subroutine.program_unit.parse_tree_path
    source_path = path_names.get(module_path.stem.lower(),'')
    unnecessary_subroutines_by_module[source_path].append(subroutine)

# %%
# sort modules by ratio of unnecessary subroutines to total subroutines
module_unnecessary_ratio = []
for module_path, subroutines in unnecessary_subroutines_by_module.items():
    total_subroutines = [r for r in all_tim_routines if path_names.get(r.program_unit.parse_tree_path.stem.lower(),'') == module_path]
    ratio = len(subroutines) / len(total_subroutines)
    module_unnecessary_ratio.append((module_path, ratio, len(subroutines), len(total_subroutines)))

module_unnecessary_ratio.sort(key=lambda x: x[1], reverse=True)
for module in module_unnecessary_ratio[:30]:
    print(f"Module: {module[0]}, Unnecessary Ratio: {module[1]:.2f}, Unnecessary Count: {module[2]}, Total Count: {module[3]}")
# Out:
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/fms_diag_bbox.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 10, Total Count: 10
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/fms_diag_outfield.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 29, Total Count: 29
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/affinity/fms_affinity.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 5, Total Count: 5
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/block_control/block_control.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 2, Total Count: 2
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/constants/fmsconstants.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 1, Total Count: 1
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/fms_diag_time_reduction.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 13, Total Count: 13
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/string_utils/fms_string_utils.F90, Unnecessary Ratio: 0.89, Unnecessary Count: 17, Total Count: 19
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mosaic2/mosaic2.F90, Unnecessary Ratio: 0.85, Unnecessary Count: 11, Total Count: 13
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms/fms_io.F90, Unnecessary Ratio: 0.77, Unnecessary Count: 122, Total Count: 158
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mpp/mpp_memutils.F90, Unnecessary Ratio: 0.60, Unnecessary Count: 3, Total Count: 5
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mosaic2/grid2.F90, Unnecessary Ratio: 0.59, Unnecessary Count: 13, Total Count: 22
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mpp/mpp_io.F90, Unnecessary Ratio: 0.58, Unnecessary Count: 84, Total Count: 144
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/horiz_interp/horiz_interp_type.F90, Unnecessary Ratio: 0.50, Unnecessary Count: 1, Total Count: 2
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/field_manager/field_manager.F90, Unnecessary Ratio: 0.42, Unnecessary Count: 22, Total Count: 52
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/axis_utils/axis_utils2.F90, Unnecessary Ratio: 0.38, Unnecessary Count: 3, Total Count: 8
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/astronomy/astronomy.F90, Unnecessary Ratio: 0.37, Unnecessary Count: 14, Total Count: 38
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/time_manager/time_manager.F90, Unnecessary Ratio: 0.35, Unnecessary Count: 30, Total Count: 85
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms2_io/fms_netcdf_domain_io.F90, Unnecessary Ratio: 0.35, Unnecessary Count: 14, Total Count: 40
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/coupler/coupler_types.F90, Unnecessary Ratio: 0.29, Unnecessary Count: 20, Total Count: 69
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/fms_diag_fieldbuff_update.F90, Unnecessary Ratio: 0.29, Unnecessary Count: 4, Total Count: 14
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mpp/mpp_domains.F90, Unnecessary Ratio: 0.27, Unnecessary Count: 121, Total Count: 447
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms2_io/netcdf_io.F90, Unnecessary Ratio: 0.26, Unnecessary Count: 32, Total Count: 124
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms/fms.F90, Unnecessary Ratio: 0.22, Unnecessary Count: 2, Total Count: 9
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/time_interp/time_interp.F90, Unnecessary Ratio: 0.21, Unnecessary Count: 3, Total Count: 14
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/diag_manager.F90, Unnecessary Ratio: 0.19, Unnecessary Count: 8, Total Count: 42
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/random_numbers/mersennetwister.F90, Unnecessary Ratio: 0.18, Unnecessary Count: 2, Total Count: 11
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/diag_table.F90, Unnecessary Ratio: 0.14, Unnecessary Count: 1, Total Count: 7
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/field_manager/fm_util.F90, Unnecessary Ratio: 0.14, Unnecessary Count: 4, Total Count: 29
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/random_numbers/random_numbers.F90, Unnecessary Ratio: 0.12, Unnecessary Count: 1, Total Count: 8
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms2_io/fms2_io.F90, Unnecessary Ratio: 0.12, Unnecessary Count: 1, Total Count: 8

# %%
# sort modules by ratio of unnecessary subroutines to total subroutines
module_unnecessary_ratio = []
for module_path, subroutines in unnecessary_subroutines_by_module.items():
    total_subroutines = [r for r in all_tim_routines if path_names.get(r.program_unit.parse_tree_path.stem.lower(),'') == module_path]
    ratio = len(subroutines) / len(total_subroutines)
    module_unnecessary_ratio.append((module_path, ratio, len(subroutines), len(total_subroutines)))

module_unnecessary_ratio.sort(key=lambda x: x[1], reverse=True)
for module in module_unnecessary_ratio[:30]:
    print(f"Module: {module[0]}, Unnecessary Ratio: {module[1]:.2f}, Unnecessary Count: {module[2]}, Total Count: {module[3]}")
# Out:
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/fms_diag_bbox.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 10, Total Count: 10
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/fms_diag_outfield.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 29, Total Count: 29
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/affinity/fms_affinity.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 5, Total Count: 5
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/block_control/block_control.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 2, Total Count: 2
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/constants/fmsconstants.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 1, Total Count: 1
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/fms_diag_time_reduction.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 13, Total Count: 13
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/string_utils/fms_string_utils.F90, Unnecessary Ratio: 0.89, Unnecessary Count: 17, Total Count: 19
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mosaic2/mosaic2.F90, Unnecessary Ratio: 0.85, Unnecessary Count: 11, Total Count: 13
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms/fms_io.F90, Unnecessary Ratio: 0.77, Unnecessary Count: 122, Total Count: 158
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mpp/mpp_memutils.F90, Unnecessary Ratio: 0.60, Unnecessary Count: 3, Total Count: 5
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mosaic2/grid2.F90, Unnecessary Ratio: 0.59, Unnecessary Count: 13, Total Count: 22
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mpp/mpp_io.F90, Unnecessary Ratio: 0.58, Unnecessary Count: 84, Total Count: 144
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/horiz_interp/horiz_interp_type.F90, Unnecessary Ratio: 0.50, Unnecessary Count: 1, Total Count: 2
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/field_manager/field_manager.F90, Unnecessary Ratio: 0.42, Unnecessary Count: 22, Total Count: 52
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/axis_utils/axis_utils2.F90, Unnecessary Ratio: 0.38, Unnecessary Count: 3, Total Count: 8
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/astronomy/astronomy.F90, Unnecessary Ratio: 0.37, Unnecessary Count: 14, Total Count: 38
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/time_manager/time_manager.F90, Unnecessary Ratio: 0.35, Unnecessary Count: 30, Total Count: 85
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms2_io/fms_netcdf_domain_io.F90, Unnecessary Ratio: 0.35, Unnecessary Count: 14, Total Count: 40
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/coupler/coupler_types.F90, Unnecessary Ratio: 0.29, Unnecessary Count: 20, Total Count: 69
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/fms_diag_fieldbuff_update.F90, Unnecessary Ratio: 0.29, Unnecessary Count: 4, Total Count: 14
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mpp/mpp_domains.F90, Unnecessary Ratio: 0.27, Unnecessary Count: 121, Total Count: 447
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms2_io/netcdf_io.F90, Unnecessary Ratio: 0.26, Unnecessary Count: 32, Total Count: 124
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms/fms.F90, Unnecessary Ratio: 0.22, Unnecessary Count: 2, Total Count: 9
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/time_interp/time_interp.F90, Unnecessary Ratio: 0.21, Unnecessary Count: 3, Total Count: 14
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/diag_manager.F90, Unnecessary Ratio: 0.19, Unnecessary Count: 8, Total Count: 42
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/random_numbers/mersennetwister.F90, Unnecessary Ratio: 0.18, Unnecessary Count: 2, Total Count: 11
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/diag_table.F90, Unnecessary Ratio: 0.14, Unnecessary Count: 1, Total Count: 7
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/field_manager/fm_util.F90, Unnecessary Ratio: 0.14, Unnecessary Count: 4, Total Count: 29
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/random_numbers/random_numbers.F90, Unnecessary Ratio: 0.12, Unnecessary Count: 1, Total Count: 8
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms2_io/fms2_io.F90, Unnecessary Ratio: 0.12, Unnecessary Count: 1, Total Count: 8

# %%
# sort modules by ratio of unnecessary subroutines to total subroutines
module_unnecessary_ratio = []
for module_path, subroutines in unnecessary_subroutines_by_module.items():
    total_subroutines = [r for r in all_tim_routines if path_names.get(r.program_unit.parse_tree_path.stem.lower(),'') == module_path]
    ratio = len(subroutines) / len(total_subroutines)
    module_unnecessary_ratio.append((module_path, ratio, len(subroutines), len(total_subroutines)))

module_unnecessary_ratio.sort(key=lambda x: x[2], reverse=True)
for module in module_unnecessary_ratio[:30]:
    print(f"Module: {module[0]}, Unnecessary Ratio: {module[1]:.2f}, Unnecessary Count: {module[2]}, Total Count: {module[3]}")
# Out:
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms/fms_io.F90, Unnecessary Ratio: 0.77, Unnecessary Count: 122, Total Count: 158
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mpp/mpp_domains.F90, Unnecessary Ratio: 0.27, Unnecessary Count: 121, Total Count: 447
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mpp/mpp_io.F90, Unnecessary Ratio: 0.58, Unnecessary Count: 84, Total Count: 144
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms2_io/netcdf_io.F90, Unnecessary Ratio: 0.26, Unnecessary Count: 32, Total Count: 124
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mpp/mpp.F90, Unnecessary Ratio: 0.08, Unnecessary Count: 31, Total Count: 377
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/time_manager/time_manager.F90, Unnecessary Ratio: 0.35, Unnecessary Count: 30, Total Count: 85
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/fms_diag_outfield.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 29, Total Count: 29
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/field_manager/field_manager.F90, Unnecessary Ratio: 0.42, Unnecessary Count: 22, Total Count: 52
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/coupler/coupler_types.F90, Unnecessary Ratio: 0.29, Unnecessary Count: 20, Total Count: 69
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/string_utils/fms_string_utils.F90, Unnecessary Ratio: 0.89, Unnecessary Count: 17, Total Count: 19
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/astronomy/astronomy.F90, Unnecessary Ratio: 0.37, Unnecessary Count: 14, Total Count: 38
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms2_io/fms_netcdf_domain_io.F90, Unnecessary Ratio: 0.35, Unnecessary Count: 14, Total Count: 40
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mosaic2/grid2.F90, Unnecessary Ratio: 0.59, Unnecessary Count: 13, Total Count: 22
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/fms_diag_time_reduction.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 13, Total Count: 13
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms2_io/fms_io_utils.F90, Unnecessary Ratio: 0.12, Unnecessary Count: 12, Total Count: 100
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mosaic2/mosaic2.F90, Unnecessary Ratio: 0.85, Unnecessary Count: 11, Total Count: 13
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/fms_diag_bbox.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 10, Total Count: 10
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/diag_manager.F90, Unnecessary Ratio: 0.19, Unnecessary Count: 8, Total Count: 42
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/affinity/fms_affinity.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 5, Total Count: 5
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/diag_util.F90, Unnecessary Ratio: 0.12, Unnecessary Count: 5, Total Count: 41
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/fms_diag_fieldbuff_update.F90, Unnecessary Ratio: 0.29, Unnecessary Count: 4, Total Count: 14
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/field_manager/fm_util.F90, Unnecessary Ratio: 0.14, Unnecessary Count: 4, Total Count: 29
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/axis_utils/axis_utils2.F90, Unnecessary Ratio: 0.38, Unnecessary Count: 3, Total Count: 8
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/mpp/mpp_memutils.F90, Unnecessary Ratio: 0.60, Unnecessary Count: 3, Total Count: 5
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/time_interp/time_interp.F90, Unnecessary Ratio: 0.21, Unnecessary Count: 3, Total Count: 14
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/diag_manager/diag_axis.F90, Unnecessary Ratio: 0.09, Unnecessary Count: 2, Total Count: 23
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/random_numbers/mersennetwister.F90, Unnecessary Ratio: 0.18, Unnecessary Count: 2, Total Count: 11
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/time_interp/time_interp_external2.F90, Unnecessary Ratio: 0.11, Unnecessary Count: 2, Total Count: 19
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/block_control/block_control.F90, Unnecessary Ratio: 1.00, Unnecessary Count: 2, Total Count: 2
# Module: /glade/work/altuntas/turbo-stack/dev-utils/../submodules/TIM/fms/fms.F90, Unnecessary Ratio: 0.22, Unnecessary Count: 2, Total Count: 9
