# %%
import networkx as nx
from pathlib import Path

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from flinspect.gen_dependency_graph import gen_module_dependency_graph, gen_call_graph
from flinspect.parse_tree import ParseTree

# %% [markdown]
# # Generate Call Graph

# %% [markdown]
# # Plot Module Dependency Graph

# %%
build_dirs = [
    "/glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/",
    #"/glade/work/altuntas/turbo-stack/bin/flang_ptree/MOM6"
]

parse_tree_files = [f for dir in build_dirs for f in Path(dir).glob("*_ptree")]

# %%
G = gen_module_dependency_graph(parse_tree_files)
assert nx.is_directed_acyclic_graph(G)
# Out:
# Warning: Skipping mpp_memuse.o_ptree as it does not start with proper header.
# Warning: Skipping fms_string_utils_binding.o_ptree as it does not start with proper header.
# Warning: Skipping mppnccombine.o_ptree as it does not start with proper header.
# Warning: Skipping mosaic_util.o_ptree as it does not start with proper header.
# Warning: Skipping gradient_c2l.o_ptree as it does not start with proper header.
# Warning: Skipping affinity.o_ptree as it does not start with proper header.
# Warning: Skipping interp.o_ptree as it does not start with proper header.
# Warning: Skipping read_mosaic.o_ptree as it does not start with proper header.
# Warning: Skipping create_xgrid.o_ptree as it does not start with proper header.
# Warning: Skipping yaml_parser_binding.o_ptree as it does not start with proper header.
# Warning: Skipping yaml_output_functions.o_ptree as it does not start with proper header.

# %%
# Determine source paths via the path_names files in build dirs
# This will be used to color nodes and edges based on where modules are located
path_names = {}
for build_dir in build_dirs:
    path_names_file = Path(build_dir)/"path_names"
    with open(path_names_file) as f:
        for line in f:
            src_file_path = Path(line.strip())
            path_names[src_file_path.stem.lower()] = src_file_path.as_posix()

# %%
def get_color(G, node):
    source_name = G.nodes[node].get('source_name','')
    source_path = path_names.get(source_name.lower(),'')
    
    node_color, edge_color = "grey", "lightgrey"
    if "/config_src/infra" in source_path:
        node_color, edge_color = "darkred", "red"    
    elif "/MARBL/" in source_path:
        node_color, edge_color = "purple", "orchid"
    elif "/CVMix-src/" in source_path:
        node_color, edge_color = "chocolate", "sandybrown"
    elif "/GSW-Fortran/" in source_path:
        node_color, edge_color = "royalblue", "cornflowerblue"
    elif "/MOM6/" in source_path:
        node_color, edge_color = "lightseagreen", "turquoise" # for core MOM6        
    elif "/FMS/" in source_path:
        node_color, edge_color = "orange", "gold"
        
    return node_color, edge_color

# %%
# Determine Node positions using 'fdp' layout
pos = nx.nx_agraph.graphviz_layout(G, prog='fdp')

# %%
from pyvis.network import Network

# %%
net = Network(notebook=True, directed=True, height='800px', cdn_resources='in_line')

net.set_options("""
var options = {
  "physics": { "enabled": false },
  "nodes": { "shape": "dot", "size": 10 },
  "edges": { "arrows": { "to": { "enabled": true, "scaleFactor": 0.3 }    } }
}
""")

# Add nodes with positions
for node in G.nodes():
    node_color, _ = get_color(G, node)
    x, y = pos[node]
    net.add_node(str(node), color=node_color, label=str(node), x=x, y=y, fixed=True)  # y flipped for browser coord system

# Add edges
for source, target in G.edges():
    _, edge_color = get_color(G, source)
    net.add_edge(str(source), str(target), color=edge_color)

# %%
# 3232 or 3164
len(G.edges)
# Out:
# 327

# %%
# net.show("module_dependency.html")

# %%
from flinspect.parse_tree import *
from flinspect.utils import *

# %% [markdown]
# # Plot Call Graph

# %%
nr = gen_call_graph(parse_tree_files);
# Out:
# Warning: Skipping mpp_memuse.o_ptree as it does not start with proper header.
# Warning: Skipping fms_string_utils_binding.o_ptree as it does not start with proper header.
# Warning: Skipping mppnccombine.o_ptree as it does not start with proper header.
# Warning: Skipping mosaic_util.o_ptree as it does not start with proper header.
# Warning: Skipping gradient_c2l.o_ptree as it does not start with proper header.
# Warning: Skipping affinity.o_ptree as it does not start with proper header.
# Warning: Skipping interp.o_ptree as it does not start with proper header.
# Warning: Skipping read_mosaic.o_ptree as it does not start with proper header.
# Warning: Skipping create_xgrid.o_ptree as it does not start with proper header.
# Warning: Skipping yaml_parser_binding.o_ptree as it does not start with proper header.
# Warning: Skipping yaml_output_functions.o_ptree as it does not start with proper header.
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_version in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_ntiles in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_size_for_all_tiles in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_size_for_one_tile in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_get_compute_domain in any used module of grid_mod for call in get_grid_cell_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_get_compute_domain'
# Could not find callee get_grid_size in any used module of grid_mod for call in get_grid_cell_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'get_grid_size'
# Could not find callee get_grid_cell_vertices in any used module of grid_mod for call in get_grid_cell_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'get_grid_cell_vertices'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee get_grid_cell_area in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'get_grid_cell_area'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_get_compute_domain in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_get_compute_domain'
# Could not find callee get_grid_size in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'get_grid_size'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_comp_area_sg in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_get_compute_domain in any used module of grid_mod for call in get_grid_cell_area_ug in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_get_compute_domain'
# Could not find callee mpp_pass_sg_to_ug in any used module of grid_mod for call in get_grid_cell_area_ug in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_pass_sg_to_ug'
# Could not find callee mpp_get_compute_domain in any used module of grid_mod for call in get_grid_comp_area_ug in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_get_compute_domain'
# Could not find callee mpp_pass_sg_to_ug in any used module of grid_mod for call in get_grid_comp_area_ug in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_pass_sg_to_ug'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_get_compute_domain in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'mpp_get_compute_domain'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_get_global_domain in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_get_global_domain'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_vertices_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_get_compute_domain in any used module of grid_mod for call in get_grid_cell_vertices_ug in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_get_compute_domain'
# Could not find callee mpp_pass_sg_to_ug in any used module of grid_mod for call in get_grid_cell_vertices_ug in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_pass_sg_to_ug'
# Could not find callee mpp_pass_sg_to_ug in any used module of grid_mod for call in get_grid_cell_vertices_ug in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_pass_sg_to_ug'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_get_compute_domain in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'mpp_get_compute_domain'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_get_global_domain in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_get_global_domain'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of grid_mod for call in get_grid_cell_centers_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_get_compute_domain in any used module of grid_mod for call in get_grid_cell_centers_ug in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_get_compute_domain'
# Could not find callee mpp_pass_sg_to_ug in any used module of grid_mod for call in get_grid_cell_centers_ug in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_pass_sg_to_ug'
# Could not find callee mpp_pass_sg_to_ug in any used module of grid_mod for call in get_grid_cell_centers_ug in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_pass_sg_to_ug'
# Could not find callee get_grid_size in any used module of grid_mod for call in define_cube_mosaic in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'get_grid_size'
# Could not find callee read_data in any used module of grid_mod for call in define_cube_mosaic in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/grid.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_xgrid in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_xgrid in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_xgrid in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_xgrid in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_xgrid in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee read_compressed in any used module of mosaic_mod for call in get_mosaic_xgrid in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'read_compressed'
# Could not find callee read_compressed in any used module of mosaic_mod for call in get_mosaic_xgrid in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'read_compressed'
# Could not find callee read_compressed in any used module of mosaic_mod for call in get_mosaic_xgrid in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'read_compressed'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_grid_sizes in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee read_data in any used module of mosaic_mod for call in get_mosaic_grid_sizes in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_grid_sizes in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_grid_sizes in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee read_data in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee read_data in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee read_data in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'read_data'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in get_mosaic_contact in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in transfer_to_model_index in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in calc_mosaic_grid_area in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in calc_mosaic_grid_area in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee get_grid_area in any used module of mosaic_mod for call in calc_mosaic_grid_area in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'get_grid_area'
# Could not find callee mpp_error in any used module of mosaic_mod for call in calc_mosaic_grid_great_circle_area in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in calc_mosaic_grid_great_circle_area in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee get_grid_great_circle_area in any used module of mosaic_mod for call in calc_mosaic_grid_great_circle_area in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'get_grid_great_circle_area'
# Could not find callee mpp_error in any used module of mosaic_mod for call in parse_string in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of mosaic_mod for call in parse_string in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mosaic.o_ptree, line: | | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee constants_init in any used module of astronomy_mod for call in astronomy_init in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/astronomy.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'constants_init'
# Could not find callee daily_mean_solar in any used module of astronomy_mod for call in annual_mean_solar_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/astronomy.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'daily_mean_solar'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in ensemble_manager_init in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in ensemble_manager_init in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in ensemble_manager_init in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in ensemble_manager_init in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_manager_init in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in get_ensemble_pelist in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in get_ensemble_pelist in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in get_ensemble_pelist in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in get_ensemble_pelist in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in get_ensemble_pelist in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in get_ensemble_pelist in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in get_ensemble_pelist in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in get_ensemble_filter_pelist in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in get_ensemble_filter_pelist in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in get_ensemble_filter_pelist in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in get_ensemble_filter_pelist in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in get_ensemble_filter_pelist in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee mpp_declare_pelist in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_declare_pelist'
# Could not find callee fms2_io_set_filename_appendix in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'fms2_io_set_filename_appendix'
# Could not find callee fms_io_set_filename_appendix in any used module of ensemble_manager_mod for call in ensemble_pelist_setup in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/ensemble_manager.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'fms_io_set_filename_appendix'
# Could not find callee mpp_error in any used module of atmos_ocean_fluxes_mod for call in aof_set_coupler_flux in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/atmos_ocean_fluxes.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_error in any used module of atmos_ocean_fluxes_mod for call in aof_set_coupler_flux in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/atmos_ocean_fluxes.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# ...
# Could not find callee mpp_sum in any used module of mpp_mod for call in mpp_gather_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_sum'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_gather_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_gather_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_gather_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_gather_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_gather_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_gather_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_gather_real8_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_gather_real8_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_gather_real8_1d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_gather_real8_1dv in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_gather_real8_1dv in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_gather in any used module of mpp_mod for call in mpp_gather_pelist_real8_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_gather'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_gather_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_max in any used module of mpp_mod for call in mpp_gather_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_max'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_gather_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_sum in any used module of mpp_mod for call in mpp_gather_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_sum'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_gather_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_gather_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_gather_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_gather_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_gather_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_gather_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_scatter in any used module of mpp_mod for call in mpp_scatter_pelist_int4_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_scatter'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_int4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_max in any used module of mpp_mod for call in mpp_scatter_pelist_int4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_max'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_int4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_sum in any used module of mpp_mod for call in mpp_scatter_pelist_int4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_sum'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_int4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_scatter_pelist_int4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_int4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_scatter_pelist_int4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_scatter_pelist_int4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_scatter_pelist_int4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_scatter in any used module of mpp_mod for call in mpp_scatter_pelist_int8_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_scatter'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_int8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_max in any used module of mpp_mod for call in mpp_scatter_pelist_int8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_max'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_int8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_sum in any used module of mpp_mod for call in mpp_scatter_pelist_int8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_sum'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_int8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_scatter_pelist_int8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_int8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_scatter_pelist_int8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_scatter_pelist_int8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_scatter_pelist_int8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_scatter in any used module of mpp_mod for call in mpp_scatter_pelist_real4_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_scatter'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_max in any used module of mpp_mod for call in mpp_scatter_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_max'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_sum in any used module of mpp_mod for call in mpp_scatter_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_sum'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_scatter_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_scatter_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_scatter_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_scatter_pelist_real4_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_scatter in any used module of mpp_mod for call in mpp_scatter_pelist_real8_2d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_scatter'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_max in any used module of mpp_mod for call in mpp_scatter_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_max'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_sum in any used module of mpp_mod for call in mpp_scatter_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | ProcedureDesignator -> Name = 'mpp_sum'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_scatter_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Could not find callee mpp_error in any used module of mpp_mod for call in mpp_scatter_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_error'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_scatter_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_send in any used module of mpp_mod for call in mpp_scatter_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | | | | ProcedureDesignator -> Name = 'mpp_send'
# Could not find callee mpp_recv in any used module of mpp_mod for call in mpp_scatter_pelist_real8_3d in /glade/work/altuntas/turbo-stack/bin/flang_ptree/FMS/mpp.o_ptree, line: | | | | | | | | | ProcedureDesignator -> Name = 'mpp_recv'
# Warning: The following modules were skipped due to missing parse tree paths:
# 	omp_lib, netcdf_nf_data, netcdf_nf_interfaces, netcdf4_nf_interfaces, netcdf, iso_c_binding, iso_fortran_env, mpi

# %%
from flinspect.parse_node import Module, Program, Subprogram, Subroutine, Function

# %%
len(path_names)
# Out:
# 207

# %%
len(nr._store[Module])
# Out:
# 73

# %%
len(nr._store[Subroutine])
# Out:
# 1693

# %%
len(nr._store[Function])
# Out:
# 649

# %%
len(nr._store[Subprogram])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [20], in <cell line: 0>()
# ----> 1 len(nr._store[Subprogram])
#
# KeyError: <class 'flinspect.parse_node.Subprogram'>

# %%
from flinspect.parse_node import Callable

# %%
import gc
num_edges = 0
for obj in gc.get_objects():
    if isinstance(obj, Callable):
        if obj.callees:
            callee_names = [callee.name for callee in obj.callees]
            if num_edges < (cutoff := 20):
                print(f"caller: {obj}, callee: {callee_names}")
            elif num_edges == cutoff:
                print("...")
        
            num_edges += len(callee_names)

print(f"\nTotal edges (i.e., calls) in call graph: {num_edges}")
# Out:
# caller: register_variable_attribute_0d, callee: ['check_netcdf_code', 'set_netcdf_mode']
# caller: register_variable_attribute_1d, callee: ['check_netcdf_code', 'set_netcdf_mode']
# caller: get_global_attribute_0d, callee: ['check_netcdf_code']
# caller: get_global_attribute_1d, callee: ['check_netcdf_code']
# caller: get_variable_attribute_0d, callee: ['check_netcdf_code']
# caller: get_variable_attribute_1d, callee: ['check_netcdf_code']
# caller: compressed_write_3d, callee: ['compressed_write_4d']
# caller: netcdf_file_close_wrap, callee: ['netcdf_file_close']
# caller: netcdf_add_variable_wrap, callee: ['netcdf_add_variable']
# caller: netcdf_save_restart_wrap, callee: ['netcdf_save_restart']
# caller: flush_file, callee: ['check_netcdf_code']
# caller: get_peset, callee: ['expand_peset']
# caller: mpp_sync, callee: ['increment_current_clock', 'system_clock_mpi']
# caller: mpp_sync_self, callee: ['increment_current_clock', 'system_clock_mpi']
# caller: mpp_error_ia, callee: ['mpp_error_basic']
# caller: mpp_error_ra, callee: ['mpp_error_basic']
# ...
#
# Total edges (i.e., calls) in call graph: 1426
